# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron


#트레이닝 셋 만들기

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([0,1,1,1])

# 퍼셉트론 러닝
clf = Perceptron()
clf.fit(X,y)

#학습된 가중치 출력
print("가중치 벡터 w = ", clf.coef_)
print("y-절편 = ",clf.intercept_)

#Plotting Results
plt.figure(figsize=(5,5))

#positive와 negative 샘플 분리하여 플롯
plt.scatter(X[y==0, 0], X[y==0, 1], c ='b', marker ='x', label='Negative 0' )
plt.scatter(X[y==1, 0], X[y==1, 1], c ='g', marker ='o', label='Positive 1' )

#경계 직선의 x 좌표와 y좌표 계산
x_values = np.array([X[:,0].min()-0.5, X[:,0].max()+0.5])
y_values = -(clf.coef_[0][0] * x_values + clf.intercept_[0]) / clf.coef_[0][1]

#경계 직선 그리기
plt.plot(x_values, y_values, c='red', label='Decision Boundary')

#기타 그래프 설정

plt.xlim([X[:,0].min()-0.5, X[:, 0].max()+0.5])
plt.ylim([X[:,1].min()-0.5, X[:, 1].max()+0.5])

plt.grid(True)
plt.xlabel("X1")
plt.ylabel("X2")
plt.title("OR Gater perceptron")
plt.legend(loc='best')
plt.show()
# Out:
# 가중치 벡터 w =  [[2. 2.]]
# y-절편 =  [-1.]

# %%
import numpy as np
from sklearn import confusion_matrix

# 데이터 셋 선언
digits = datasets.load_digits()
print(digits.data.shape)
print(digits.target.shape)

#데이터셋을 Training set과 Test Set으로 분할
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, train_size=0.05,random_state =4)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 from sklearn import confusion_matrix
#       4 # 데이터 셋 선언
#       5 digits = datasets.load_digits()
#
# ImportError: cannot import name 'confusion_matrix' from 'sklearn' (/Users/mac/.pyenv/versions/3.11.2/lib/python3.11/site-packages/sklearn/__init__.py)

# %%
from sklearn import datasets
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import numpy as np

#데이터 로드
digits = datasets.load_digits()

#데이터 셋 분리
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, train_size=0.5,random_state=42)

# MLP 러닝

clf = MLPClassifier(hidden_layer_sizes=(100,), learning_rate_init=.001,
                    batch_size=32,max_iter=300, solver='sgd',  verbose =1)
clf.fit(X_train,y_train)

#학습 결과 분석

acc = clf.score(X_test, y_test)
print("정확도 = ", acc) 

#confusion matrix 계산
print("\nConfusion Matrix")
cm = confusion_matrix(y_test, clf.predict(X_test))
print("cm :", cm)
# Out:
# Iteration 1, loss = 2.62564454
# Iteration 2, loss = 0.31317789
# Iteration 3, loss = 0.19854806
# Iteration 4, loss = 0.14971377
# Iteration 5, loss = 0.12015488
# Iteration 6, loss = 0.09918522
# Iteration 7, loss = 0.08596031
# Iteration 8, loss = 0.07385104
# Iteration 9, loss = 0.06780503
# Iteration 10, loss = 0.06023513
# Iteration 11, loss = 0.06075491
# Iteration 12, loss = 0.04872360
# Iteration 13, loss = 0.04643928
# Iteration 14, loss = 0.04295592
# Iteration 15, loss = 0.03814860
# Iteration 16, loss = 0.03695489
# Iteration 17, loss = 0.03558572
# Iteration 18, loss = 0.03530210
# Iteration 19, loss = 0.03432909
# Iteration 20, loss = 0.02997565
# Iteration 21, loss = 0.02690599
# Iteration 22, loss = 0.02499277
# Iteration 23, loss = 0.02407343
# Iteration 24, loss = 0.02230387
# Iteration 25, loss = 0.02204693
# Iteration 26, loss = 0.02645332
# Iteration 27, loss = 0.02129262
# Iteration 28, loss = 0.01861270
# Iteration 29, loss = 0.01819011
# Iteration 30, loss = 0.01778731
# Iteration 31, loss = 0.01812849
# Iteration 32, loss = 0.01819903
# Iteration 33, loss = 0.01578474
